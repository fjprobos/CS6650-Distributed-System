# %%
import pandas
import plotly.express

# %%
df = pandas.read_csv('G:/My Drive/Northeastern/CS6650 - Scalable Distributed Systems/Repos/Java/lab4/massiveUpload.csv')
df[df["phase"]=="Phase 3"].head()
# Out:
#                        task    phase  numberOfRequestsPerThread  \
# 4864  Post Latency Analysis  Phase 3                         19
# 4865  Post Latency Analysis  Phase 3                         19
# 4866  Post Latency Analysis  Phase 3                         19
# 4867  Post Latency Analysis  Phase 3                         19
# 4868  Post Latency Analysis  Phase 3                         19
#
#                        threadId  requestId                    start  \
# 4864  lab4.SkierClient@3b0c58a6          0  2022-02-16 02:47:52.146
# 4865  lab4.SkierClient@3b0c58a6          1  2022-02-16 02:47:53.557
# 4866  lab4.SkierClient@3b0c58a6          2  2022-02-16 02:47:55.205
# 4867  lab4.SkierClient@3b0c58a6          3  2022-02-16 02:47:55.474
# 4868  lab4.SkierClient@3b0c58a6          4  2022-02-16 02:47:55.815
#
#                           end  duration
# 4864  2022-02-16 02:47:53.487    1341.0
# 4865  2022-02-16 02:47:55.135    1578.0
# 4866  2022-02-16 02:47:55.472     267.0
# ...

# %%
fig = plotly.express.scatter(df, x='start', y='duration', color='phase')

# %%
fig.show()
# Out:
# <div>
#
#
#             <div id="dc2caeb0-32cd-4307-81ae-10920e9c3650" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dc2caeb0-32cd-4307-81ae-10920e9c3650")) {
#                     Plotly.newPlot(
#                         'dc2caeb0-32cd-4307-81ae-10920e9c3650',
# ...

# %%
len(df)
# Out:
# 5704
